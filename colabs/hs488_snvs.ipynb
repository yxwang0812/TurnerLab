# %% [markdown]
# <a href="https://colab.research.google.com/github/yxwang0812/TurnerLab/blob/main/colabs/hs488_snvs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Batch variant scoring

# %% [markdown]
# In this notebook, we demonstrate how to score many variants using AlphaGenome.
#
# To prepare numerous variants for scoring, provide the following information as columns in a tab-separated Variant Call Format (VCF) file:
# - `variant_id`: A unique identifier for each variant.
# - `CHROM`: Chromosome, specified as a string beginning with 'chr' (e.g., 'chr1').
# - `POS`: Integer representing the base pair position (1-based; build hg38 (human) or mm10 (mouse) - see [FAQ](https://www.alphagenomedocs.com/faqs.html#how-do-i-define-a-variant)).
# - `REF`: The reference nucleotide sequence at the specified position.
# - `ALT`: The alternate nucleotide sequence at the specified position.

# %% [markdown]
# ```{tip}
# Open this tutorial in Google colab for interactive viewing.
# ```

# %%
from IPython.display import clear_output
! pip install alphagenome
clear_output()

# %%
from io import StringIO
from alphagenome.data import genome
from alphagenome.models import dna_client, variant_scorers
from alphagenome.visualization import plot_components
from google.colab import data_table, files
from google.colab import userdata
import pandas as pd
from tqdm import tqdm

data_table.enable_dataframe_formatter()

# Load the model.
dna_model = dna_client.create(userdata.get('ALPHA_GENOME_API_KEY'))

# %%
# Single variant
variant = genome.Variant(
    chromosome='chr13',
    position=94706909,
    reference_bases='G',
    alternate_bases='A'
)

interval = variant.reference_interval.resize(dna_client.SEQUENCE_LENGTH_1MB)

variant_output = dna_model.predict_variant(
    interval=interval,
    variant=variant,
    requested_outputs=[dna_client.OutputType.RNA_SEQ],
    ontology_terms=['UBERON:0000955'],
)  # Brain


variant_output.reference.rna_seq # TrackData
variant_output.reference.rna_seq.metadata
variant_output.reference.rna_seq.values # track predictions
# Out:
# array([[4.6253204e-05, 1.9073486e-06],
#        [7.3432922e-05, 2.8759241e-06],
#        [1.1205673e-04, 3.9935112e-06],
#        ...,
#        [5.5506825e-07, 1.8119812e-05],
#        [2.1010637e-06, 6.0558319e-05],
#        [4.1127205e-06, 1.0871887e-04]], dtype=float32)

# %%
vcf_file = """variant_id\tCHROM\tPOS\tREF\tALT
SP0168279_chr13_94706909_G_A_WGS1\tchr13\t94706909\tG\tA
SP0290557_chr13_94707484_C_T_WGS4\tchr13\t94707484\tC\tT
SP0039814_chr13_94706430_A_G_WGS5\tchr13\t94706430\tA\tG
"""
vcf = pd.read_csv(StringIO(vcf_file), sep='\t')

required_columns = ['variant_id', 'CHROM', 'POS', 'REF', 'ALT']
for column in required_columns:
  if column not in vcf.columns:
    raise ValueError(f'VCF file is missing required column: {column}.')

organism = 'human'

sequence_length = '1MB'
sequence_length = dna_client.SUPPORTED_SEQUENCE_LENGTHS[
    f'SEQUENCE_LENGTH_{sequence_length}'
]

results = []

for i, vcf_row in tqdm(vcf.iterrows(), total=len(vcf)):
  variant = genome.Variant(
      chromosome=str(vcf_row.CHROM),
      position=int(vcf_row.POS),
      reference_bases=vcf_row.REF,
      alternate_bases=vcf_row.ALT,
      name=vcf_row.variant_id,
  )
  interval = variant.reference_interval.resize(sequence_length)
  variant_prediction = dna_model.predict_variant(
    interval=interval,
    variant=variant,
    requested_outputs=[dna_client.OutputType.RNA_SEQ],
    ontology_terms=['UBERON:0000955'],
  )
  results.append(variant_prediction.reference.rna_seq.values)
  results.append(variant_prediction.alternate.rna_seq.values)

print(results)
# Out:
# 100%|██████████| 3/3 [00:04<00:00,  1.45s/it]
# [array([[4.6253204e-05, 1.9073486e-06],
#        [7.3432922e-05, 2.8759241e-06],
#        [1.1205673e-04, 3.9935112e-06],
#        ...,
#        [5.5506825e-07, 1.8119812e-05],
#        [2.1010637e-06, 6.0558319e-05],
#        [4.1127205e-06, 1.0871887e-04]], dtype=float32), array([[4.6253204e-05, 1.9073486e-06],
#        [7.6293945e-05, 2.8759241e-06],
#        [1.1205673e-04, 3.9935112e-06],
#        ...,
#        [5.5506825e-07, 1.9550323e-05],
#        [2.1010637e-06, 6.0558319e-05],
#        [4.1127205e-06, 1.0871887e-04]], dtype=float32), array([[7.3432922e-05, 2.2202730e-06],
#        [1.2683868e-04, 3.6954880e-06],
#        [1.9168854e-04, 5.1558018e-06],
#        ...,
#        [2.9504299e-06, 4.1484833e-05],
#        [1.0311604e-05, 1.3351440e-04],
#        [1.6927719e-05, 2.3078918e-04]], dtype=float32), array([[7.3432922e-05, 2.2202730e-06],
#        [1.2683868e-04, 3.6954880e-06],
#        [1.9168854e-04, 5.1558018e-06],
#        ...,
#        [2.9504299e-06, 4.1484833e-05],
#        [1.0311604e-05, 1.3351440e-04],
#        [1.6927719e-05, 2.3078918e-04]], dtype=float32), array([[2.5749207e-05, 1.9073486e-06],
#        [4.2438507e-05, 3.1143427e-06],
#        [5.6982040e-05, 3.9935112e-06],
#        ...,
#        [5.5506825e-07, 8.5234642e-06],
#        [1.9520521e-06, 2.7537346e-05],
#        [4.1127205e-06, 4.6730042e-05]], dtype=float32), array([[2.3722649e-05, 1.9073486e-06],
#        [4.2438507e-05, 3.1143427e-06],
#        [5.6982040e-05, 3.6954880e-06],
#        ...,
#        [5.5506825e-07, 8.5234642e-06],
#        [1.9520521e-06, 2.5153160e-05],
#        [4.1127205e-06, 4.6730042e-05]], dtype=float32)]

# %%
score_rna_seq = True  # @param { type: "boolean"}
score_cage = True  # @param { type: "boolean" }
score_procap = True  # @param { type: "boolean" }
score_atac = True  # @param { type: "boolean" }
score_dnase = True  # @param { type: "boolean" }
score_chip_histone = True  # @param { type: "boolean" }
score_chip_tf = True  # @param { type: "boolean" }
score_polyadenylation = True  # @param { type: "boolean" }
score_splice_sites = True  # @param { type: "boolean" }
score_splice_site_usage = True  # @param { type: "boolean" }
score_splice_junctions = True  # @param { type: "boolean" }

download_predictions = False  # @param { type: "boolean" }

organism_map = {
    'human': dna_client.Organism.HOMO_SAPIENS,
    'mouse': dna_client.Organism.MUS_MUSCULUS,
}
organism = organism_map[organism]

scorer_selections = {
    'rna_seq': score_rna_seq,
    'cage': score_cage,
    'procap': score_procap,
    'atac': score_atac,
    'dnase': score_dnase,
    'chip_histone': score_chip_histone,
    'chip_tf': score_chip_tf,
    'polyadenylation': score_polyadenylation,
    'splice_sites': score_splice_sites,
    'splice_site_usage': score_splice_site_usage,
    'splice_junctions': score_splice_junctions,
}

all_scorers = variant_scorers.RECOMMENDED_VARIANT_SCORERS
selected_scorers = [
    all_scorers[key]
    for key in all_scorers
    if scorer_selections.get(key.lower(), False)
]

# Remove any scorers or output types that are not supported for the chosen organism.
unsupported_scorers = [
    scorer
    for scorer in selected_scorers
    if (
        organism.value
        not in variant_scorers.SUPPORTED_ORGANISMS[scorer.base_variant_scorer]
    )
    | (
        (scorer.requested_output == dna_client.OutputType.PROCAP)
        & (organism == dna_client.Organism.MUS_MUSCULUS)
    )
]
if len(unsupported_scorers) > 0:
  print(
      f'Excluding {unsupported_scorers} scorers as they are not supported for'
      f' {organism}.'
  )
  for unsupported_scorer in unsupported_scorers:
    selected_scorers.remove(unsupported_scorer)


# Score variants in the VCF file.
results = []

for i, vcf_row in tqdm(vcf.iterrows(), total=len(vcf)):
  variant = genome.Variant(
      chromosome=str(vcf_row.CHROM),
      position=int(vcf_row.POS),
      reference_bases=vcf_row.REF,
      alternate_bases=vcf_row.ALT,
      name=vcf_row.variant_id,
  )
  interval = variant.reference_interval.resize(sequence_length)

  variant_scores = dna_model.score_variant(
      interval=interval,
      variant=variant,
      variant_scorers=selected_scorers,
      organism=organism,
  )
  results.append(variant_scores)

df_scores = variant_scorers.tidy_scores(results)

if download_predictions:
  df_scores.to_csv('variant_scores.csv', index=False)
  files.download('variant_scores.csv')

df_scores
# Out:
# 100%|██████████| 3/3 [00:06<00:00,  2.05s/it]
# Warning: total number of rows (31485) exceeds max_rows (20000). Falling back to pandas display.
#                variant_id            scored_interval          gene_id  \
# 0      chr13:94706909:G>A  chr13:94182621-95231197:.             None
# 1      chr13:94706909:G>A  chr13:94182621-95231197:.             None
# 2      chr13:94706909:G>A  chr13:94182621-95231197:.             None
# 3      chr13:94706909:G>A  chr13:94182621-95231197:.             None
# 4      chr13:94706909:G>A  chr13:94182621-95231197:.             None
# ...                   ...                        ...              ...
# 31480  chr13:94706430:A>G  chr13:94182142-95230718:.  ENSG00000260962
# 31481  chr13:94706430:A>G  chr13:94182142-95230718:.  ENSG00000274168
# 31482  chr13:94706430:A>G  chr13:94182142-95230718:.  ENSG00000287635
# 31483  chr13:94706430:A>G  chr13:94182142-95230718:.  ENSG00000289204
# 31484  chr13:94706430:A>G  chr13:94182142-95230718:.  ENSG00000289878
#
#              gene_name gene_type gene_strand junction_Start junction_End  \
# 0                 None      None        None           None         None
# 1                 None      None        None           None         None
# 2                 None      None        None           None         None
# 3                 None      None        None           None         None
# 4                 None      None        None           None         None
# ...                ...       ...         ...            ...          ...
# 31480        LINC00557    lncRNA           +           None         None
# 31481        RN7SL585P  misc_RNA           -           None         None
# 31482  ENSG00000287635    lncRNA           -           None         None
# 31483  ENSG00000289204    lncRNA           +           None         None
# 31484  ENSG00000289878    lncRNA           -           None         None
#
#       output_type                                     variant_scorer  ...  \
# 0            ATAC  CenterMaskScorer(requested_output=ATAC, width=...  ...
# 1            ATAC  CenterMaskScorer(requested_output=ATAC, width=...  ...
# 2            ATAC  CenterMaskScorer(requested_output=ATAC, width=...  ...
# 3            ATAC  CenterMaskScorer(requested_output=ATAC, width=...  ...
# 4            ATAC  CenterMaskScorer(requested_output=ATAC, width=...  ...
# ...           ...                                                ...  ...
# 31480     RNA_SEQ        GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 31481     RNA_SEQ        GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 31482     RNA_SEQ        GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 31483     RNA_SEQ        GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
# 31484     RNA_SEQ        GeneMaskLFCScorer(requested_output=RNA_SEQ)  ...
#
#       track_strand         Assay title  ontology_curie  \
# 0                .            ATAC-seq      CL:0000084
# 1                .            ATAC-seq      CL:0000100
# 2                .            ATAC-seq      CL:0000236
# 3                .            ATAC-seq      CL:0000623
# 4                .            ATAC-seq      CL:0000624
# ...            ...                 ...             ...
# 31480            .  polyA plus RNA-seq  UBERON:0036149
# 31481            .  polyA plus RNA-seq  UBERON:0036149
# 31482            .  polyA plus RNA-seq  UBERON:0036149
# 31483            .  polyA plus RNA-seq  UBERON:0036149
# 31484            .  polyA plus RNA-seq  UBERON:0036149
#
#                         biosample_name                 biosample_type  \
# 0                               T-cell                   primary_cell
# 1                         motor neuron  in_vitro_differentiated_cells
# 2                               B cell                   primary_cell
# 3                  natural killer cell                   primary_cell
# 4      CD4-positive, alpha-beta T cell                   primary_cell
# ...                                ...                            ...
# 31480                  suprapubic skin                         tissue
# 31481                  suprapubic skin                         tissue
# 31482                  suprapubic skin                         tissue
# 31483                  suprapubic skin                         tissue
# 31484                  suprapubic skin                         tissue
#
#       transcription_factor histone_mark                      gtex_tissue  \
# 0                      NaN          NaN                              NaN
# 1                      NaN          NaN                              NaN
# 2                      NaN          NaN                              NaN
# 3                      NaN          NaN                              NaN
# 4                      NaN          NaN                              NaN
# ...                    ...          ...                              ...
# 31480                  NaN          NaN  Skin_Not_Sun_Exposed_Suprapubic
# 31481                  NaN          NaN  Skin_Not_Sun_Exposed_Suprapubic
# 31482                  NaN          NaN  Skin_Not_Sun_Exposed_Suprapubic
# 31483                  NaN          NaN  Skin_Not_Sun_Exposed_Suprapubic
# 31484                  NaN          NaN  Skin_Not_Sun_Exposed_Suprapubic
#
#       raw_score  quantile_score
# 0     -0.017078       -0.599367
# 1      0.013206        0.291254
# 2     -0.014325       -0.511872
# 3      0.000499       -0.046111
# 4     -0.025337       -0.721776
# ...         ...             ...
# 31480 -0.000340       -0.270000
# 31481 -0.008290       -0.992509
# 31482 -0.000303       -0.237625
# 31483  0.000337        0.270000
# 31484  0.000473        0.343112
#
# [31485 rows x 21 columns]

# %%
columns = [c for c in df_scores.columns if c != 'ontology_curie']
df_scores[(df_scores['ontology_curie'] == 'UBERON:0000955')][columns]
# Out:
#                variant_id            scored_interval          gene_id  \
# 388    chr13:94706909:G>A  chr13:94182621-95231197:.             None
# 1994   chr13:94706909:G>A  chr13:94182621-95231197:.             None
# 2887   chr13:94706909:G>A  chr13:94182621-95231197:.             None
# 2888   chr13:94706909:G>A  chr13:94182621-95231197:.             None
# 2889   chr13:94706909:G>A  chr13:94182621-95231197:.             None
# ...                   ...                        ...              ...
# 28323  chr13:94706430:A>G  chr13:94182142-95230718:.  ENSG00000237924
# 28324  chr13:94706430:A>G  chr13:94182142-95230718:.  ENSG00000238230
# 28325  chr13:94706430:A>G  chr13:94182142-95230718:.  ENSG00000274168
# 28326  chr13:94706430:A>G  chr13:94182142-95230718:.  ENSG00000287635
# 28327  chr13:94706430:A>G  chr13:94182142-95230718:.  ENSG00000289878
#
#              gene_name             gene_type gene_strand junction_Start  \
# 388               None                  None        None           None
# 1994              None                  None        None           None
# 2887              None                  None        None           None
# 2888              None                  None        None           None
# 2889              None                  None        None           None
# ...                ...                   ...         ...            ...
# 28323        RPL21P112  processed_pseudogene           -           None
# 28324        LINC00391                lncRNA           -           None
# 28325        RN7SL585P              misc_RNA           -           None
# 28326  ENSG00000287635                lncRNA           -           None
# 28327  ENSG00000289878                lncRNA           -           None
#
#       junction_End   output_type  \
# 388           None         DNASE
# 1994          None       CHIP_TF
# 2887          None  CHIP_HISTONE
# 2888          None  CHIP_HISTONE
# 2889          None  CHIP_HISTONE
# ...            ...           ...
# 28323         None       RNA_SEQ
# 28324         None       RNA_SEQ
# 28325         None       RNA_SEQ
# 28326         None       RNA_SEQ
# 28327         None       RNA_SEQ
#
#                                           variant_scorer  \
# 388    CenterMaskScorer(requested_output=DNASE, width...
# 1994   CenterMaskScorer(requested_output=CHIP_TF, wid...
# 2887   CenterMaskScorer(requested_output=CHIP_HISTONE...
# 2888   CenterMaskScorer(requested_output=CHIP_HISTONE...
# 2889   CenterMaskScorer(requested_output=CHIP_HISTONE...
# ...                                                  ...
# 28323        GeneMaskLFCScorer(requested_output=RNA_SEQ)
# 28324        GeneMaskLFCScorer(requested_output=RNA_SEQ)
# 28325        GeneMaskLFCScorer(requested_output=RNA_SEQ)
# 28326        GeneMaskLFCScorer(requested_output=RNA_SEQ)
# 28327        GeneMaskLFCScorer(requested_output=RNA_SEQ)
#
#                                      track_name track_strand  \
# 388                    UBERON:0000955 DNase-seq            .
# 1994            UBERON:0000955 TF ChIP-seq CTCF            .
# 2887   UBERON:0000955 Histone ChIP-seq H3K27me3            .
# 2888   UBERON:0000955 Histone ChIP-seq H3K36me3            .
# 2889    UBERON:0000955 Histone ChIP-seq H3K4me1            .
# ...                                         ...          ...
# 28323         UBERON:0000955 polyA plus RNA-seq            -
# 28324         UBERON:0000955 polyA plus RNA-seq            -
# 28325         UBERON:0000955 polyA plus RNA-seq            -
# 28326         UBERON:0000955 polyA plus RNA-seq            -
# 28327         UBERON:0000955 polyA plus RNA-seq            -
#
#               Assay title biosample_name biosample_type transcription_factor  \
# 388             DNase-seq          brain         tissue                  NaN
# 1994          TF ChIP-seq          brain       organoid                 CTCF
# 2887     Histone ChIP-seq          brain         tissue                  NaN
# 2888     Histone ChIP-seq          brain         tissue                  NaN
# 2889     Histone ChIP-seq          brain         tissue                  NaN
# ...                   ...            ...            ...                  ...
# 28323  polyA plus RNA-seq          brain         tissue                  NaN
# 28324  polyA plus RNA-seq          brain         tissue                  NaN
# 28325  polyA plus RNA-seq          brain         tissue                  NaN
# 28326  polyA plus RNA-seq          brain         tissue                  NaN
# 28327  polyA plus RNA-seq          brain         tissue                  NaN
#
#       histone_mark gtex_tissue  raw_score  quantile_score
# 388            NaN         NaN  -0.038481   -7.379445e-01
# 1994           NaN         NaN   0.025267    8.535151e-01
# 2887      H3K27me3         NaN  -0.001413   -2.267112e-01
# 2888      H3K36me3         NaN   0.000324    1.137757e-12
# 2889       H3K4me1         NaN  -0.001354   -2.047139e-01
# ...            ...         ...        ...             ...
# 28323          NaN              -0.000499   -4.218197e-01
# 28324          NaN              -0.009642   -9.954839e-01
# 28325          NaN              -0.012149   -9.975752e-01
# 28326          NaN               0.000579    4.680602e-01
# 28327          NaN               0.000319    3.532494e-01
#
# [78 rows x 20 columns]
